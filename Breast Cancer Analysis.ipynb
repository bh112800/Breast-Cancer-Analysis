# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("breast cancer.csv")

# %% [markdown]
# ## Data Exploration

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.shape
# Out:
# (569, 33)

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Checking for null values
data.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Dropping the Unnamed Column
data.drop(columns="Unnamed: 32", inplace=True)

# %%
data.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
# Visualizing the counts of diagnosis 
sns.countplot(data.diagnosis);
plt.title("Counts of Diagnosis")
plt.xlabel("Diagnosis")
# Out:
# Text(0.5, 0, 'Diagnosis')

# %%
# Scatterplot using pairs
sns.pairplot(data[["diagnosis", "radius_mean", "texture_mean", "perimeter_mean", "area_mean"]], hue="diagnosis")
plt.show()

# %%
# 
size = len(data['texture_mean'])

area = np.pi * (15 * np.random.rand( size ))**2
colors = np.random.rand( size )

plt.xlabel("texture mean")
plt.ylabel("radius mean") 
plt.scatter(data['texture_mean'], data['radius_mean'], s=area, c=colors, alpha=0.5);

# %%
# Converting the diagnosis into numerical categorical column
from sklearn.preprocessing import LabelEncoder

labelencoder_Y = LabelEncoder()
data.diagnosis = labelencoder_Y.fit_transform(data.diagnosis)

# %%
data.head(3)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38           122.8     1001.0
# 1    842517          1        20.57         17.77           132.9     1326.0
# 2  84300903          1        19.69         21.25           130.0     1203.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33            184.6      2019.0
# 1  ...         24.99          23.41            158.8      1956.0
# 2  ...         23.57          25.53            152.5      1709.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# ...

# %% [markdown]
# "1" refers to malignant and "0" refers to benign

# %%
# Correlation and Heatmap
var = ['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
data[var].corr()

# Heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(data[var].corr(), cmap="Blues", annot=True)
plt.title("Correlation plot")
# Out:
# Text(0.5, 1.0, 'Correlation plot')

# %% [markdown]
# ## Data Splitting

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split

X = data[['radius_mean',  'perimeter_mean', 'area_mean', 'symmetry_mean', 'compactness_mean', 'concave points_mean']]
y = data.diagnosis

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
# Scaling the data
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# ## Model Implementation

# %%
# Knn
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
param_knn = {'n_neighbors': range(1, 30)} 
grid_knn = GridSearchCV(knn, param_knn, cv = 5)
grid_knn.fit(X_train, y_train)

print('kNN: Best Paramater is', grid_knn.best_params_)
print('kNN: Best Mean Validation Score is', grid_knn.best_score_)
print("kNN: Accuarcy is", grid_knn.score(X_test, y_test))
# Out:
# kNN: Best Paramater is {'n_neighbors': 6}
# kNN: Best Mean Validation Score is 0.9347468354430379
# kNN: Accuarcy is 0.8830409356725146

# %%
# Decision Tree
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
param_grid = {'max_depth':  range(1,10)         ,
              'min_samples_split':   range(2,11),
              'max_leaf_nodes':    range(2,11)   }


grid_tree = GridSearchCV(model, param_grid, cv=10)

grid_tree.fit(X_train, y_train) 

print("Decision Tree: Best Parameter is", grid_tree.best_params_)
print("Decision Tree: Best Score is", grid_tree.best_score_)
print("Decision Tree: Accuarcy is", grid_tree.score(X_test, y_test))
# Out:
# Decision Tree: Best Parameter is {'max_depth': 2, 'max_leaf_nodes': 4, 'min_samples_split': 2}
# Decision Tree: Best Score is 0.9498076923076922
# Decision Tree: Accuarcy is 0.8830409356725146

# %% [markdown]
# ## Model Evaluation

# %%
# kNN
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

knn_y_test_pred = grid_knn.predict(X_test)

print('kNN: Precision score:', precision_score(y_test, knn_y_test_pred))
print('kNN: Recall score:', recall_score(y_test, knn_y_test_pred))
print('kNN: Accuracy score:', accuracy_score(y_test, knn_y_test_pred))
print('kNN: F1 score:', f1_score(y_test, knn_y_test_pred))

# Precision-recall curve
from sklearn.metrics import precision_recall_curve

knn_prob = grid_knn.predict_proba(X_test)[:, 1]

knn_precision, knn_recall, knn_threshold = precision_recall_curve(y_test, knn_prob) # 3 outputs

# Plot
plt.plot(knn_recall, knn_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('kNN: Precision-Recall curve')

# AUC
from sklearn.metrics import roc_auc_score

print("kNN: AUC value is",  roc_auc_score(y_test, knn_prob) )
# Out:
# kNN: Precision score: 0.875
# kNN: Recall score: 0.8235294117647058
# kNN: Accuracy score: 0.8830409356725146
# kNN: F1 score: 0.8484848484848485
# kNN: AUC value is 0.9201884637350086

# %%
# Decision Tree
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

tree_y_test_pred = grid_tree.predict(X_test)

print('Decision Tree: Precision score:', precision_score(y_test, tree_y_test_pred))
print('Decision Tree: Recall score:', recall_score(y_test, tree_y_test_pred))
print('Decision Tree: Accuracy score:', accuracy_score(y_test, tree_y_test_pred))
print('Decision Tree: F1 score:', f1_score(y_test, tree_y_test_pred))

# Precision-recall curve
from sklearn.metrics import precision_recall_curve

tree_prob = grid_tree.predict_proba(X_test)[:, 1]

tree_precision, tree_recall, tree_threshold = precision_recall_curve(y_test, tree_prob) # 3 outputs

# Plot
plt.plot(tree_recall, tree_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Decision Tree: Precision-Recall curve')

# AUC
from sklearn.metrics import roc_auc_score

print("Decision Tree: AUC value is",  roc_auc_score(y_test, tree_prob) )
# Out:
# Decision Tree: Precision score: 0.8243243243243243
# Decision Tree: Recall score: 0.8970588235294118
# Decision Tree: Accuracy score: 0.8830409356725146
# Decision Tree: F1 score: 0.8591549295774648
# Decision Tree: AUC value is 0.903055396916048
